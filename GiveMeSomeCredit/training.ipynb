# %%
from pandas import DataFrame, read_csv, to_numeric, Series
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, auc, roc_auc_score
import matplotlib.pyplot as plt
from bigml.api import BigML
import kaggle
from pprint import pprint

# %matplotlib inline

# %%
compression = True  #Do we compress the csv files?

version='v1.3'

big_ml_project = 'project/5d94a428eba31d460c00023f'

# %%
if compression:
    compress='.bz2'
else:
    compress=''
  
filename_fulltrain = 'gmsc-fulltrain-' + version + '.csv'+ compress
filename_train = 'gmsc-train80-' + version + '.csv'+ compress
filename_valid = 'gmsc-valid20-' + version + '.csv'+ compress
filename_test = 'gmsc-test-' + version + '.csv'+ compress

filename_bigml_ids = 'bigml-' + version + '.csv'+ compress

# %% [markdown]
# ## Send the data to BigML and create an ensemble model

# %%
api = BigML(project=big_ml_project)

train_src = api.create_source(filename_train)
api.ok(train_src)
valid_src = api.create_source(filename_valid)
api.ok(valid_src)
test_src = api.create_source(filename_test)
api.ok(test_src)

print("Sources created")
# Out:
# Sources created

# %%
train_ds = api.create_dataset(train_src)
api.ok(train_ds)
valid_ds = api.create_dataset(valid_src)
api.ok(valid_src)
test_ds = api.create_dataset(test_src)
api.ok(test_src)
print("Data sets created")
# Out:
# Data sets created

# %%
model_args= {"objective_field": "SeriousDlqin2yrs"}
model = api.create_ensemble(train_ds, model_args)
api.ok(model)
print("Model created")
# Out:
# Model created

# %%
bigml_ids = {}
bigml_ids['training source']=train_src['resource']
bigml_ids['validation source']=valid_src['resource']
bigml_ids['test source']=test_src['resource']

bigml_ids['training dataset']=train_ds['resource']
bigml_ids['validation dataset']=valid_ds['resource']
bigml_ids['test dataset']=test_ds['resource']

bigml_ids['model']=model['resource']

pprint(bigml_ids)

Series(bigml_ids).to_csv(filename_bigml_ids, header=False)
# Out:
# {'model': 'ensemble/5db3a3a55299631c8200a5ed',
#  'test dataset': 'dataset/5db3a3a07811dd7f2d00a008',
#  'test source': 'source/5db3a35de47684746800ad95',
#  'training dataset': 'dataset/5db3a385e47684746800ad9b',
#  'training source': 'source/5db3a34b7811dd7f2d00a002',
#  'validation dataset': 'dataset/5db3a39fe47684746800ad9e',
#  'validation source': 'source/5db3a356e47684746800ad92'}

# %%
model
# Out:
# {'code': 200,
#  'resource': 'ensemble/5db3a3a55299631c8200a5ed',
#  'location': 'https://bigml.io/andromeda/ensemble/5db3a3a55299631c8200a5ed',
#  'object': {'boosting': None,
#   'category': 0,
#   'code': 200,
#   'columns': 12,
#   'configuration': None,
#   'configuration_status': False,
#   'created': '2019-10-26T01:38:45.029000',
#   'creator': 'guillaume33',
#   'credits': 41.01543045043945,
#   'credits_per_prediction': 0.0,
#   'dataset': 'dataset/5db3a385e47684746800ad9b',
#   'dataset_field_types': {'categorical': 2,
#    'datetime': 0,
#    'items': 0,
#    'numeric': 11,
#    'preferred': 12,
#    'text': 0,
#    'total': 13},
#   'dataset_status': True,
#   'depth_threshold': 512,
#   'description': '',
#   'distributions': [{'importance': [['000001', 0.31159],
#      ['000002', 0.21869],
#      ['000003', 0.10552],
#      ['000006', 0.10338],
#      ['00000a', 0.06326],
#      ['000007', 0.05758],
#      ['000004', 0.03933],
#      ['000008', 0.03919],
#      ['00000b', 0.03876],
#      ['000005', 0.0227]],
#     'predictions': {'categories': [['0', 117171], ['1', 2829]]},
#     'training': {'categories': [['0', 112231], ['1', 7769]]}},
#    {'importance': [['000001', 0.30051],
#      ['000002', 0.21897],
#      ['000004', 0.08022],
#      ['000003', 0.07673],
#      ['000006', 0.06724],
#      ['000008', 0.05841],
#      ['000007', 0.05803],
#      ['00000a', 0.05773],
#      ['000005', 0.04681],
#      ['00000b', 0.03535]],
#     'predictions': {'categories': [['0', 117434], ['1', 2566]]},
#     'training': {'categories': [['0', 112235], ['1', 7765]]}},
#    {'importance': [['000001', 0.30271],
#      ['000002', 0.21725],
#      ['000003', 0.08889],
#      ['00000a', 0.08058],
#      ['000006', 0.07488],
#      ['000007', 0.07267],
#      ['000004', 0.06453],
#      ['000005', 0.036],
#      ['00000b', 0.0314],
#      ['000008', 0.03109]],
#     'predictions': {'categories': [['0', 117085], ['1', 2915]]},
#     'training': {'categories': [['0', 112060], ['1', 7940]]}},
#    {'importance': [['000001', 0.32142],
#      ['000002', 0.23094],
#      ['000003', 0.10169],
#      ['00000a', 0.08711],
#      ['000006', 0.07327],
#      ['000004', 0.05155],
#      ['000007', 0.04954],
#      ['000008', 0.03717],
#      ['000005', 0.02994],
#      ['00000b', 0.01737]],
#     'predictions': {'categories': [['0', 117094], ['1', 2906]]},
#     'training': {'categories': [['0', 112102], ['1', 7898]]}},
#    {'importance': [['000001', 0.30856],
#      ['000002', 0.22471],
#      ['000003', 0.09953],
#      ['000006', 0.0969],
#      ['000007', 0.06764],
#      ['00000a', 0.05564],
#      ['000008', 0.04901],
#      ['000004', 0.04374],
#      ['000005', 0.0379],
#      ['00000b', 0.01637]],
#     'predictions': {'categories': [['0', 117628], ['1', 2372]]},
#     'training': {'categories': [['0', 111981], ['1', 8019]]}},
#    {'importance': [['000001', 0.31267],
#      ['000002', 0.23105],
#      ['000006', 0.11591],
#      ['000003', 0.0963],
#      ['000007', 0.06036],
#      ['000004', 0.05911],
#      ['00000a', 0.05909],
#      ['000005', 0.02457],
#      ['000008', 0.02341],
#      ['00000b', 0.01753]],
#     'predictions': {'categories': [['0', 117643], ['1', 2357]]},
#     'training': {'categories': [['0', 112057], ['1', 7943]]}},
#    {'importance': [['000001', 0.32712],
#      ['000002', 0.21912],
#      ['000003', 0.1011],
#      ['000007', 0.07371],
#      ['00000a', 0.05542],
#      ['00000b', 0.05083],
#      ['000006', 0.04973],
#      ['000004', 0.04862],
#      ['000008', 0.0381],
#      ['000005', 0.03625]],
#     'predictions': {'categories': [['0', 117361], ['1', 2639]]},
#     'training': {'categories': [['0', 112123], ['1', 7877]]}},
#    {'importance': [['000001', 0.33805],
#      ['000002', 0.24229],
#      ['000003', 0.08396],
#      ['000004', 0.07436],
#      ['000007', 0.07025],
#      ['000006', 0.056],
#      ['00000a', 0.04859],
#      ['00000b', 0.04393],
#      ['000005', 0.02142],
#      ['000008', 0.02115]],
#     'predictions': {'categories': [['0', 117092], ['1', 2908]]},
#     'training': {'categories': [['0', 112095], ['1', 7905]]}},
#    {'importance': [['000001', 0.31177],
#      ['000002', 0.24319],
#      ['000003', 0.08989],
#      ['00000a', 0.07451],
#      ['000005', 0.06365],
#      ['000006', 0.05898],
#      ['000004', 0.05198],
#      ['000007', 0.04931],
#      ['000008', 0.04186],
#      ['00000b', 0.01485]],
#     'predictions': {'categories': [['0', 117831], ['1', 2169]]},
#     'training': {'categories': [['0', 111892], ['1', 8108]]}},
#    {'importance': [['000001', 0.30473],
#      ['000002', 0.24889],
#      ['000003', 0.09806],
#      ['00000a', 0.07897],
#      ['000006', 0.07505],
#      ['000007', 0.06214],
#      ['000004', 0.04837],
#      ['000008', 0.03605],
#      ['00000b', 0.02529],
#      ['000005', 0.02246]],
#     'predictions': {'categories': [['0', 117201], ['1', 2799]]},
#     'training': {'categories': [['0', 112127], ['1', 7873]]}}],
#   'ensemble': {'fields': {'000001': {'column_number': 1,
#      'datatype': 'int8',
#      'name': 'LateScore',
#      'optype': 'numeric',
#      'order': 0,
#      'preferred': True,
#      'summary': {'bins': [[0.09628, 105960],
#        [2.45919, 7485],
#        [4.38992, 2539],
#        [6.36689, 1480],
#        [8.47865, 890],
#        [10.41015, 473],
#        [12.41408, 355],
#        [14.51786, 224],
#        [16.47619, 126],
#        [18.33784, 74],
#        [20.42857, 49],
#        [22.47222, 36],
#        [24.46154, 26],
#        [26.65, 20],
#        [28.33333, 15],
#        [30, 6],
#        [31, 1],
#        [32, 4],
#        [33, 3],
#        [34, 2],
#        [35, 1],
#        [36, 1],
#        [37, 1],
#        [38, 1],
#        [39, 2],
#        [40, 1],
#        [41, 1],
#        [44, 3],
#        [45, 1],
#        [46, 2],
#        [47, 1],
#        [51, 1]],
#       'kurtosis': 62.64691,
#       'maximum': 51,
#       'mean': 0.64551,
#       'median': 0.2554,
#       'minimum': 0,
#       'missing_count': 216,
#       'population': 119784,
#       'skewness': 6.33902,
#       'standard_deviation': 2.08175,
#       'sum': 77322,
#       'sum_squares': 569012,
#       'variance': 4.33367}},
#     '000002': {'column_number': 2,
#      'datatype': 'double',
#      'name': 'RevolvingUtilizationOfUnsecuredLines',
#      'optype': 'numeric',
#      'order': 1,
#      'preferred': True,
#      'summary': {'bins': [[0.3312, 119833],
#        [336.23485, 11],
#        [671.125, 8],
#        [995.25, 20],
#        [1594.6875, 16],
#        [1978.13636, 22],
#        [2459.53333, 15],
#        [3138.4, 10],
#        [3707.71429, 14],
#        [4189, 8],
#        [4659, 5],
#        [5074.66667, 3],
#        [5437, 2],
#        [6048.5, 6],
#        [6770.66667, 3],
#        [7096, 1],
#        [7761.2, 5],
#        [8412.5, 2],
#        [8770.5, 2],
#        [9340, 1],
#        [9684, 1],
#        [10209, 1],
#        [11843, 1],
#        [12369, 1],
#        [13498, 1],
#        [13930, 1],
#        [17441, 1],
#        [18300, 1],
#        [20514, 1],
#        [22099, 2],
#        [29110, 1],
#        [50708, 1]],
#       'kurtosis': 14512.56925,
#       'maximum': 50708,
#       'mean': 6.15667,
#       'median': 0.56534,
#       'minimum': 0,
#       'missing_count': 0,
#       'population': 120000,
#       'skewness': 99.72172,
#       'standard_deviation': 263.47954,
#       'sum': 738800.14883,
#       'sum_squares': 8335055050.14594,
#       'variance': 69421.46604}},
#     '000003': {'column_number': 3,
#      'datatype': 'int8',
#      'name': 'age',
#      'optype': 'numeric',
#      'order': 2,
#      'preferred': True,
#      'summary': {'bins': [[22.68925, 1284],
#        [25.53766, 2496],
#        [28.61252, 4248],
#        [31.15411, 3251],
#        [34.03853, 6593],
#        [37.43466, 6237],
#        [40.02787, 4664],
#        [42.19802, 7691],
#        [45.77525, 11012],
#        [49.53554, 11536],
#        [53.01096, 8574],
#        [55.93699, 8411],
#        [58.48624, 5378],
#        [60.52607, 5408],
#        [62.92576, 7422],
#        [64.93408, 4263],
#        [67.23479, 4472],
#        [69.48177, 2962],
#        [71.50247, 2631],
#        [73.92744, 3404],
#        [76.95651, 2667],
#        [79.47773, 1482],
#        [81.86954, 1533],
#        [85.11775, 1172],
#        [88.22558, 727],
#        [90.9661, 295],
#        [93.80556, 144],
#        [97.17647, 34],
#        [101.6, 5],
#        [105, 1],
#        [107, 1],
#        [109, 2]],
#       'kurtosis': -0.49555,
#       'maximum': 109,
#       'mean': 52.28614,
#       'median': 51.75245,
#       'minimum': 21,
#       'missing_count': 0,
#       'population': 120000,
#       'skewness': 0.18805,
#       'standard_deviation': 14.76255,
#       'sum': 6274337,
#       'sum_squares': 354212595,
#       'variance': 217.93283}},
#     '000004': {'column_number': 4,
#      'datatype': 'double',
#      'name': 'DebtRatio',
#      'optype': 'numeric',
#      'order': 3,
#      'preferred': True,
#      'summary': {'bins': [[0.41846, 94496],
#        [145.80886, 42],
#        [305.93169, 61],
#        [457.77011, 29],
#        [627.51563, 32],
#        [768.34, 25],
#        [892.78571, 14],
#        [990.94118, 17],
#        [1091.8, 15],
#        [1256.96512, 43],
#        [1423.02381, 21],
#        [1630.55, 20],
#        [1798.47368, 19],
#        [1968.5, 11],
#        [2099.0625, 8],
#        [2214.75, 2],
#        [2313.75, 2],
#        [2438.83333, 3],
#        [2572, 2],
#        [2684, 2],
#        [2842.16667, 3],
#        [2982.1, 5],
#        [3205.5, 1],
#        [3449, 2],
#        [3949, 1],
#        [4396.5, 1],
#        [4815.5, 1],
#        [5209.5, 1],
#        [5342, 1],
#        [5815.75, 2],
#        [7065.5, 1],
#        [61106.5, 1]],
#       'exact_histogram': {'open_max': 341,
#        'populations': [94341,
#         75,
#         24,
#         17,
#         15,
#         7,
#         7,
#         5,
#         6,
#         5,
#         4,
#         3,
#         2,
#         4,
#         4,
#         1,
#         2,
#         3,
#         8,
#         3,
#         1,
#         1,
#         2,
#         3],
#        'start': 0,
#        'width': 10},
#       'kurtosis': 64744.02702,
#       'maximum': 61106.5,
#       'mean': 5.43525,
#       'median': 0.29218,
#       'minimum': 0,
#       'missing_count': 25116,
#       'population': 94884,
#       'skewness': 233.51611,
#       'standard_deviation': 218.28491,
#       'sum': 515717.98887,
#       'sum_squares': 4523816754.12918,
#       'variance': 47648.30053}},
#     '000005': {'column_number': 5,
#      'datatype': 'int32',
#      'name': 'MonthlyIncome',
#      'optype': 'numeric',
#      'order': 4,
#      'preferred': True,
#      'summary': {'bins': [[4732.04784, 117582],
#        [21263.0773, 1617],
#        [31252.30286, 350],
#        [41205.2191, 178],
#        [51648.11765, 68],
#        [61688.01538, 65],
#        [72937.7, 40],
#        [84768.375, 32],
#        [98948.46667, 15],
#        [110043.71429, 7],
#        [120200, 6],
#        [128983.28571, 7],
#        [141625, 4],
#        [149951.66667, 3],
#        [159791, 1],
#        [168788.66667, 3],
#        [184903, 1],
#        [205916.5, 2],
#        [218674, 1],
#        [235666.66667, 3],
#        [250536, 3],
#        [287662, 1],
#        [304000, 1],
#        [324000, 1],
#        [428250, 1],
#        [562466, 1],
#        [649587, 1],
#        [701015, 2],
#        [835040, 1],
#        [1072500, 1],
#        [1560100, 1],
#        [3008750, 1]],
#       'kurtosis': 26800.7152,
#       'maximum': 3008750,
#       'mean': 5337.33583,
#       'median': 4902.89365,
#       'minimum': 0,
#       'missing_count': 0,
#       'population': 120000,
#       'skewness': 131.81917,
#       'standard_deviation': 12926.97297,
#       'sum': 640480300,
#       'sum_squares': 23471086963644,
#       'variance': 167106630.12117}},
#     '000006': {'column_number': 6,
#      'datatype': 'double',
#      'name': 'MonthlyDebt',
#      'optype': 'numeric',
#      'order': 5,
#      'preferred': True,
#      'summary': {'bins': [[1723.9821, 115315],
#        [6897.72942, 3772],
#        [11483.22397, 492],
#        [15275.596, 200],
#        [20595.13142, 71],
#        [26960.29407, 51],
#        [33747.63464, 18],
#        [40178.47622, 13],
#        [45035.67039, 9],
#        [51151.81538, 10],
#        [54945.26102, 7],
#        [61231.20727, 4],
#        [65970.21602, 4],
#        [73597.82252, 6],
#        [90733.65684, 1],
#        [100155.59128, 3],
#        [106128.84735, 4],
#        [110952, 1],
#        [122558.24968, 1],
#        [151374.98974, 2],
#        [157281.79813, 3],
#        [207245.389, 1],
#        [220516, 1],
#        [246351.93061, 2],
#        [251709.67353, 1],
#        [264732.8263, 1],
#        [295087.1473, 1],
#        [328053, 2],
#        [357531.36777, 1],
#        [422571.8286, 1],
#        [474639.28777, 1],
#        [478450.55916, 1]],
#       'kurtosis': 4742.67116,
#       'maximum': 478450.55916,
#       'mean': 2047.40057,
#       'median': 1830.13457,
#       'minimum': 0,
#       'missing_count': 0,
#       'population': 120000,
#       'skewness': 55.84592,
#       'standard_deviation': 4344.27958,
#       'sum': 245688068.0077,
#       'sum_squares': 2767734828360.014,
#       'variance': 18872765.09539}},
#     '000007': {'column_number': 7,
#      'datatype': 'double',
#      'name': 'BalancedIncome',
#      'optype': 'numeric',
#      'order': 6,
#      'preferred': True,
#      'summary': {'bins': [[3386.96947, 74189],
#        [9712.94386, 14743],
#        [21815.95625, 792],
#        [31466.8363, 146],
#        [39632.34083, 136],
#        [49238.47309, 58],
#        [59610.65892, 41],
#        [68243.45025, 27],
#        [75672.93884, 20],
#        [85314.50192, 26],
#        [97272.30161, 11],
#        [106546.02034, 3],
#        [115309.53222, 8],
#        [124483.67167, 8],
#        [139443.76538, 4],
#        [149433.68692, 3],
#        [167714.33844, 3],
#        [184780.00068, 1],
#        [204903.00607, 2],
#        [220442.52655, 2],
#        [231323.52061, 2],
#        [247194.67998, 3],
#        [265624.65328, 2],
#        [284227.01195, 1],
#        [427155.00244, 1],
#        [561596.00178, 1],
#        [648734.00133, 1],
#        [696817.50597, 2],
#        [834917.00028, 1],
#        [1067634.00422, 1],
#        [1553840.00358, 1],
#        [3004327.00211, 1]],
#       'exact_histogram': {'open_max': 353,
#        'populations': [19012,
#         28917,
#         19222,
#         10744,
#         5666,
#         2832,
#         1398,
#         764,
#         399,
#         272,
#         171,
#         121,
#         106,
#         72,
#         65,
#         40,
#         53,
#         33],
#        'start': 0,
#        'width': 2000},
#       'kurtosis': 24062.33498,
#       'maximum': 3004327.00211,
#       'mean': 4986.41949,
#       'median': 3792.13862,
#       'minimum': 0.5,
#       'missing_count': 29760,
#       'population': 90240,
#       'skewness': 130.28251,
#       'standard_deviation': 14237.93878,
#       'sum': 449974495.12833,
#       'sum_squares': 20536912466973.195,
#       'variance': 202718900.61629}},
#     '000008': {'column_number': 8,
#      'datatype': 'double',
#      'name': 'IncomePerHouseholdMember',
#      'optype': 'numeric',
#      'order': 7,
#      'preferred': True,
#      'summary': {'bins': [[2990.02621, 88571],
#        [14552.92914, 1115],
#        [22159.11298, 241],
#        [30467.74166, 119],
#        [38213.51085, 47],
#        [44500.76336, 41],
#        [51205.68645, 14],
#        [60146.8856, 22],
#        [67979.04875, 8],
#        [76335.63254, 9],
#        [84704.49563, 10],
#        [93824.43857, 5],
#        [101315.15885, 7],
#        [113985.76848, 6],
#        [121611.05794, 4],
#        [129290.02791, 1],
#        [142113.50597, 1],
#        [153378.04021, 1],
#        [164395.25037, 2],
#        [184780.00068, 1],
#        [203492.00245, 1],
#        [213577.50122, 1],
#        [220442.52655, 2],
#        [232230.6694, 1],
#        [247423.51347, 2],
#        [265624.65328, 2],
#        [280798.00089, 1],
#        [348471.50188, 1],
#        [517946.66786, 1],
#        [533817.00211, 1],
#        [751081.75053, 1],
#        [834917.00028, 1]],
#       'exact_histogram': {'open_max': 405,
#        'populations': [16491,
#         21985,
#         16425,
#         11102,
#         7421,
#         4876,
#         3321,
#         2480,
#         1650,
#         1249,
#         998,
#         476,
#         373,
#         240,
#         185,
#         160,
#         91,
#         71,
#         53,
#         73,
#         50,
#         23,
#         42],
#        'start': 0,
#        'width': 1000},
#       'kurtosis': 5419.84332,
#       'maximum': 834917.00028,
#       'mean': 3395.7343,
#       'median': 2371.41254,
#       'minimum': 0.25,
#       'missing_count': 29760,
#       'population': 90240,
#       'skewness': 56.04964,
#       'standard_deviation': 6714.95815,
#       'sum': 306431063.36221,
#       'sum_squares': 5109494813053.45,
#       'variance': 45090663.01895}},
#     '000009': {'column_number': 9,
#      'datatype': 'string',
#      'name': 'LateCategory',
#      'optype': 'categorical',
#      'order': 8,
#      'preferred': True,
#      'summary': {'categories': [['L0', 119784], ['L98', 212], ['L96', 4]],
#       'missing_count': 0},
#      'term_analysis': {'enabled': True}},
#     '00000a': {'column_number': 10,
#      'datatype': 'int8',
#      'name': 'NumberOfOpenCreditLinesAndLoans',
#      'optype': 'numeric',
#      'order': 9,
#      'preferred': True,
#      'summary': {'bins': [[0.70082, 5134],
#        [2.57262, 12558],
#        [4.52679, 19617],
#        [6.49391, 21498],
#        [8.47342, 18983],
#        [10.46413, 14442],
#        [12.45128, 10191],
#        [14.44632, 6511],
#        [16.442, 4276],
#        [18.43383, 2660],
#        [20.42089, 1637],
#        [22.85631, 1197],
#        [24.45845, 373],
#        [26.46, 350],
#        [28.40094, 212],
#        [30.46269, 134],
#        [32.49383, 81],
#        [34.4898, 49],
#        [36.28571, 21],
#        [38.42105, 19],
#        [40.36364, 11],
#        [42.61538, 13],
#        [44, 1],
#        [45.33333, 9],
#        [47.75, 8],
#        [49.25, 4],
#        [51, 1],
#        [52, 3],
#        [53, 1],
#        [54, 3],
#        [56, 2],
#        [57, 1]],
#       'kurtosis': 3.05322,
#       'maximum': 57,
#       'mean': 8.45239,
#       'median': 7.63177,
#       'minimum': 0,
#       'missing_count': 0,
#       'population': 120000,
#       'skewness': 1.21294,
#       'standard_deviation': 5.15359,
#       'sum': 1014287,
#       'sum_squares': 11760259,
#       'variance': 26.55945}},
#     '00000b': {'column_number': 11,
#      'datatype': 'int8',
#      'name': 'NumberRealEstateLoansOrLines',
#      'optype': 'numeric',
#      'order': 10,
#      'preferred': True,
#      'summary': {'counts': [[0, 44895],
#        [1, 41967],
#        [2, 25197],
#        [3, 5019],
#        [4, 1733],
#        [5, 547],
#        [6, 256],
#        [7, 147],
#        [8, 75],
#        [9, 58],
#        [10, 29],
#        [11, 20],
#        [12, 16],
#        [13, 13],
#        [14, 5],
#        [15, 5],
#        [16, 4],
#        [17, 2],
#        [18, 1],
#        [19, 2],
#        [20, 2],
#        [21, 1],
#        [23, 2],
#        [25, 1],
#        [26, 1],
#        [29, 1],
#        [32, 1]],
#       'kurtosis': 29.50207,
#       'maximum': 32,
#       'mean': 1.01801,
#       'median': 0.8606,
#       'minimum': 0,
#       'missing_count': 0,
#       'population': 120000,
#       'skewness': 2.86754,
#       'standard_deviation': 1.12148,
#       'sum': 122161,
#       'sum_squares': 275285,
#       'variance': 1.25771}},
#     '00000c': {'column_number': 12,
#      'datatype': 'string',
#      'name': 'SeriousDlqin2yrs',
#      'optype': 'categorical',
#      'order': 11,
#      'preferred': True,
#      'summary': {'categories': [['0', 112055], ['1', 7945]],
#       'missing_count': 0},
#      'term_analysis': {'enabled': True}}}},
#   'ensemble_sample': {'rate': 1,
#    'replacement': True,
#    'seed': '2591e8aa9f5c412b9d3f71fa84c4b7cc'},
#   'error_models': 0,
#   'fields_meta': {'count': 12,
#    'limit': 1000,
#    'offset': 0,
#    'query_total': 12,
#    'total': 12},
#   'finished_models': 10,
#   'focus_field': None,
#   'focus_field_name': None,
#   'importance': {'000001': 0.31391,
#    '000002': 0.22951,
#    '000003': 0.09417,
#    '000004': 0.05618,
#    '000005': 0.03417,
#    '000006': 0.07713,
#    '000007': 0.06212,
#    '000008': 0.03754,
#    '00000a': 0.06609,
#    '00000b': 0.02917},
#   'input_fields': ['000001',
#    '000002',
#    '000003',
#    '000004',
#    '000005',
#    '000006',
#    '000007',
#    '000008',
#    '000009',
#    '00000a',
#    '00000b'],
#   'locale': 'en_US',
#   'max_columns': 13,
#   'max_rows': 120000,
#   'missing_splits': False,
#   'models': ['model/5db3a3b8440ca115b2077871',
#    'model/5db3a3b9440ca115b2077873',
#    'model/5db3a3b9440ca115b2077875',
#    'model/5db3a3b9440ca115b2077877',
#    'model/5db3a3b9440ca115b2077879',
#    'model/5db3a3b9440ca115b207787b',
#    'model/5db3a3b9440ca115b207787d',
#    'model/5db3a3ba440ca115b207787f',
#    'model/5db3a3ba440ca115b2077881',
#    'model/5db3a3ba440ca115b2077883'],
#   'name': 'gmsc-train80-v1.3.csv',
#   'name_options': 'bootstrap decision forest, 512-node, 10-model, pruned, deterministic order',
#   'node_threshold': 512,
#   'number_of_batchpredictions': 0,
#   'number_of_evaluations': 0,
#   'number_of_models': 10,
#   'number_of_predictions': 0,
#   'number_of_public_predictions': 0,
#   'objective_field': '00000c',
#   'objective_field_details': {'column_number': 12,
#    'datatype': 'string',
#    'name': 'SeriousDlqin2yrs',
#    'optype': 'categorical',
#    'order': 12},
#   'objective_field_name': 'SeriousDlqin2yrs',
#   'objective_field_type': 'categorical',
#   'objective_fields': ['00000c'],
#   'optiml': None,
#   'optiml_status': False,
#   'ordering': 0,
#   'out_of_bag': False,
#   'price': 0.0,
#   'private': True,
#   'project': 'project/5d94a428eba31d460c00023f',
#   'randomize': False,
#   'range': None,
#   'replacement': False,
#   'resource': 'ensemble/5db3a3a55299631c8200a5ed',
#   'rows': 120000,
#   'sample_rate': 1.0,
#   'selective_pruning': True,
#   'shared': False,
#   'size': 10751949,
#   'source': 'source/5db3a34b7811dd7f2d00a002',
#   'source_status': True,
#   'split_candidates': 32,
#   'split_field': None,
#   'split_field_name': None,
#   'stat_pruning': True,
#   'status': {'code': 5,
#    'elapsed': 19057,
#    'message': 'The ensemble has been created',
#    'progress': 1},
#   'subscription': True,
#   'support_threshold': 0.0,
#   'tags': [],
#   'type': 0,
#   'updated': '2019-10-26T01:39:06.720000',
#   'white_box': False},
#  'error': None}
